# %%
from sklearn.datasets import load_iris
iris=load_iris()
X=iris.data
y=iris.target

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.25)


from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier()
d.fit(X_train,y_train)
y_pred=d.predict(X_test)
print("original  :" ,y_test)
print("Predicted :" ,y_pred)

from sklearn import metrics
print("Accuracy : ",metrics.accuracy_score(y_test,y_pred))

from matplotlib import pyplot as plt
from sklearn import tree
import graphviz


fig,axes = plt.subplots(nrows=1,ncols=1,figsize=(4,4),dpi=300)
fn = ["sepal_length","sepal_width","petal_length","petal_width"]     #fn=data.feature_names
cn = ["setosa","viriginica","versicolor"]                            #cn=data.target_names
tree.plot_tree(d, 
              feature_names=fn,
              class_names=cn,
              filled=True)

fig.savefig("Image.png")
# Out:
# original  : [0 1 1 0 2 1 2 0 0 2 1 0 2 1 1 0 1 1 0 0 1 1 1 0 2 1 0 0 1 2 1 2 1 2 2 0 1
#  0]
# Predicted : [0 1 1 0 2 1 2 0 0 2 1 0 2 1 1 0 1 1 0 0 1 1 2 0 2 1 0 0 1 2 1 2 1 2 2 0 1
#  0]
# Accuracy :  0.9736842105263158
